# %% [markdown]
# # Lab 01 : Cross-entropy loss -- solution
#
# Goal:The primary objective is to understand how to quantify the performance of a classification model by calculating the Cross-Entropy loss on a small batch of data.
#
# Implement:Criterion Creation: It initializes the cross-entropy loss criterion using nn.CrossEntropyLoss().
#
# Data Preparation: It defines a set of ground-truth classification labels as a LongTensor and creates a corresponding batch of predicted scores.
#
# Loss Calculation: It demonstrates how to compute the average loss by comparing predicted scores against the actual labels, specifically aiming for scores that reflect high confidence and low error (loss $\le 0.1$).
#
# Visualization: It utilizes utility functions to visually display the score distributions for each data point in the batch.

# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/IPAM_Mar26_codes/labs_lecture03/lab01_cross_entropy'
    print(path_to_file)
    # change current path to the folder containing "file_name"
    os.chdir(path_to_file)
    # !pwd

# %%
import torch
import torch.nn as nn
import utils

# %% [markdown]
# ### Make a Cross Entropy Criterion and call it criterion. The command is nn.CrossEntropyLoss().

# %%
criterion=nn.CrossEntropyLoss()

print(criterion)
# Out:
# CrossEntropyLoss()

# %% [markdown]
# ### Suppose that there only two classes (class 0 and class 1).
# ### Suppose we have a batch of three data points:
# ### ${\bf x^{(0)}}$ belongs to class 0
# ### ${\bf x^{(1)}}$belongs to class 1
# ### ${\bf x^{(2)}}$ belongs to class 1
# ### Put the labels of each of these point a LongTensor:

# %%
labels = torch.LongTensor([0,1,1])

print(labels)
# Out:
# tensor([0, 1, 1])

# %% [markdown]
# ### Make a batch of scores: each row corresponds to the scores associated with a data point. So your batch of scores should look likes something like:
#
# $$
# \text{scores} \;\; = \;\; \begin{bmatrix}
# s_0^{(0)} & s_1^{(0)} & \\
# s_0^{(1)} & s_1^{(1)} & \\
# s_0^{(2)} & s_1^{(2)} & \\
# \end{bmatrix}
# $$
#
# ### You will need to create a tensor of the form torch.Tensor( [ [ ], [ ], [ ] ] ). Don't forget the extra square brackets!
#
# ### Choose scores that will leads to a loss very close to zero, let say around or smaller than 0.1 (indicating that the scores are very good with respect to the labels).

# %%
scores = torch.Tensor( [ [5.2,-1.2], [-1.0,4.0], [-1,2] ] )

print(scores)
# Out:
# tensor([[ 5.2000, -1.2000],
#         [-1.0000,  4.0000],
#         [-1.0000,  2.0000]])

# %% [markdown]
# ### Display your batch of scores

# %%
utils.display_scores(scores)

# %% [markdown]
# ### Compute the average loss on this batch -- it needs to be around or smaller than 0.05

# %%
average_loss = criterion( scores, labels)

print(average_loss.item())
# Out:
# 0.018987612798810005
